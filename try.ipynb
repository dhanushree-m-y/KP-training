# %%
from operator import index

s="data handling"
for ch in s:
    print(ch)
# Out:
# d
# a
# t
# a
#
# h
# a
# n
# d
# l
# i
# n
# g

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

print(type(list1))
# Out:
# <class 'list'>

# %%
# STRINGS

s =['red','blue','white','yellow','green','red','blue','white','yellow','green']
print(s[0:-1])
# Out:
# ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow']

# %%
s = ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green', "orange"]
s.remove("orange")
print(s)
# Out:
# ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green']

# %%
s = ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green', "orange"]
s.insert(2,'pink')
print(s)
# Out:
# ['red', 'blue', 'pink', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green', 'orange']

# %%
#looping through lists
s = ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green', "orange"]
for color in s:
    print(color)
# Out:
# red
# blue
# white
# yellow
# green
# red
# blue
# white
# yellow
# green
# orange

# %%
#list comprehenstion

s = ['red', 'blue', 'white', 'yellow', 'green', 'red', 'blue', 'white', 'yellow', 'green', "orange"]

# %%
#check specific character in string
s=input("eneter the character")
print('e' in s)
# Out:
# False

# %%
s="hello world"
for ch in s:
    print(ch)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
 #check the longest word in the list

words=['apple','mango','banana','cherry']
longest_word=[]
for word in words:
    if len(word)> len(longest_word):
        longest_word = word
print(longest_word)
# Out:
# banana

# %%
user_input=input("enter the names")
words= user_input.split()
longest_word=[]
for word in words:
    if len(word)> len(longest_word):
        longest_word = word
print(longest_word)
# Out:
# hfhjw

# %%
#check email is valid or not
user_input=input("enter the email")
if '@' and '.' in user_input:
    print("valid")
else:
    print("invalid")
# Out:
# invalid

# %%
s="hello world"
print(s.replace(' ','-'))
# Out:
# hello-world

# %%
cars= {'car1': 'ee', 'car2': 'ff', 'car3': 'dd'}
# user_input=input("enter the car names")
# if user_input in cars:
#         print("car found")
# else:
#         print("car not found")
print(cars)
# Out:
# {'car1': 'ee', 'car2': 'ff', 'car3': 'dd'}

# %%
cars= {'car1': 'ee', 'car2': 'ff', 'car3': 'dd'}

    # print(cars[x] #print everyitem in cars
copycars=cars.copy()
print(copycars)
# Out:
# {'car1': 'ee', 'car2': 'ff', 'car3': 'dd'}

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
if num1>num2 and num1>num3:
    print(num1,'a is getarer')
elif num2>num3 and num1:
    print(num2,'b is getrer')
else:
    print(num3,'c is getreter')
# Out:
# 4444 c is getreter

# %%
#check whether positve negative or zero
num= int(input("enter the  number"))
if num>0:
    print(num,'is positive')
elif num<0:
    print(num,'is negative')
elif num==0:
    print("zero is zero")
# Out:
# 55 is positive

# %%
#check wheteher the character is vowel or consonets
user_input=input("enetr the chararcter").lower()
vowels='a,e,i,o,u'

if user_input in vowels:
    print(vowels)
else:
    print("consosnents")
# Out:
# consosnents

# %%
user_input=input("eneter the string").lower()
vowels='a,e,i,o,u'
vowel_count=0
consonent_count =0

if user_input in vowels:
    vowel_count+=1
else:
    consonent_count+=1
print("number of vowels:",vowel_count)
print("number of consonents:",consonent_count)
# Out:
# number of vowels: 0
# number of consonents: 1

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
N=int(input("enter the number"))
i=1
while i<N:

    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
user_input=input("eneter the number")
if i%3 ==0:
        print('it is div by 3')
else:
        print('it is not div by 3')
# Out:
#   Cell In[1], line 3
#     if i%3 ==0:
#     ^
# IndentationError: unexpected indent

# %%
fruits=['apple','mango','blueberry']
s="hello world"
for x in s:
    print(x)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
fruits=['apple','mango','blueberry']
for x in fruits:
    print(x)
    if x== 'apple':
        break
# Out:
# apple

# %%
for x in range(6):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2,50,3):
    print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32
# 35
# 38
# 41
# 44
# 47

# %%
fruits=['apple','mango','blueberry']
vegetables=['tomato','raddish','onion']

for x in fruits:
    for y in vegetables:
        print(x+y)
# Out:
# appletomato
# appleraddish
# appleonion
# mangotomato
# mangoraddish
# mangoonion
# blueberrytomato
# blueberryraddish
# blueberryonion

# %%
def my_fun():
    print('hello worls')
my_fun()
# Out:
# hello worls

# %%
def display_info(name,age):
    print("name",name)
    print('age',age)

display_info('apple',20)
# Out:
# name apple
# age 20

# %%
def happy_birthday(name,age):
    print(f'happy birthday {name}')
    print(f'your are  {age} years old')
happy_birthday('dhanu',20)
# Out:
# happy birthday dhanu
# your are  20 years old

# %%
def marriage(boy,girl):
    print(f"boy is {boy}")
    print(f"girl is {girl}")
    print(f"{boy} marries a {girl}")
marriage("bibin" ,"dhnau")
# Out:
# boy is bibin
# girl is dhnau
# bibin marries a dhnau

# %%
def factorial(n):
    if n==1:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
city={
    "mysore":"mysore pake",
    "bangalore":"bangalore pak",
    "chennai":"chennai pak",
}
print(city["mysore"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
#       1 city={
#       2     "mysore":"mysore pake",
#       3     "bangalore":"bangalore pak",
#       4     "chennai":"chennai pak",
#       5 }
# ----> 6 print(city[0])
#
# KeyError: 0

# %%
user_input=input("eneter the number")
def even_odd(number):
    if number % 2 == 0:
        print(number, "is an even number")
    else:
        print(number, "is an odd number")

even_odd(num)
# Out:
# 34 is an even number

# %%
def factorial(n):
    if n==1:
        return 1
    else:
        return n*factorial(n-1)
print(factorial(5))

# %%
price1 = int(input("Enter the price of item1: "))
quantity1 = int(input("Enter the quantity of item1: "))
price2 = int(input("Enter the price of item2: "))
quantity2 = int(input("Enter the quantity of item2: "))

total = print(price1 * quantity1 + price2 * quantity2)
print(total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 price1 = int(input("Enter the price of item1: "))
#       2 quantity1 = int(input("Enter the quantity of item1: "))
#       3 price2 = int(input("Enter the price of item2: "))
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
#Tuples

my_tuple=("sav","rev",9)
my_tuple2 = (7,)          #tuple are comma separated

s=1,2,3                     #can be done without parenthesis
t="s","2",2
print(my_tuple)
print(type(my_tuple2))
print(s)
# Out:
# ('sav', 'rev', 9)
# <class 'tuple'>
# (1, 2, 3)

# %%
#tuple indexing
my_tuple=("dhnau","ulls","bibin")
s=2,3,4
print(my_tuple[0])
print(my_tuple[-1])
# Out:
# dhnau
# bibin

# %%
#tuple immutablity
#once created cant be changed

my_tuple=("dhnau","ulls","bibin")
my_tuple[0]="babitha"               #this cant be done because u cant chnaeg ir
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       1 #tuple immutablity
#       2 #once created cant be changed
#       4 my_tuple=("dhnau","ulls","bibin")
# ----> 5 my_tuple[0]="babitha"
#       6 print(my_tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# for the changing of tuple u should convert into lists

t=(1,2,3,3,5,6)
u=list(t)
u[3]=4
t=tuple(u)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#looping of tuples

my_tuple=("dhnau","ulls","bibin")
for x in my_tuple:
    print(x)
# Out:
# dhnau
# ulls
# bibin

# %%
#opertaions in tuple

my_tuple1=(1,2,2)
my_tuple2= 3,4,5

new_tuple=my_tuple1+my_tuple2
print(new_tuple)
# Out:
# (1, 2, 2, 3, 4, 5)

# %% [markdown]
# nums=10,20,30,40,20,20
# print(nums.count(20))

# %%
nums=10,20,30,40,20,20
print(nums.count(20))
print(nums.index(20))
# Out:
# 3
# 1

# %%
#unpackimg tuples
fruits=('apple','mango','blueberry')
f1,f2,f3=fruits
print(f1)
# Out:
# apple

# %%
nested=((2,3),(3,3),6)
print(nested[1][0])
# Out:
# 3

# %% [markdown]
# Strings- collection of chaaracter

# %%
word="hello worls"
for ch in word:
    print(ch)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# s

# %%
#slicing
text="hello dhanushree"
print(text[0:5])
print(len(text))
# Out:
# hello
# 16

# %%
#conacatenation
x="hello"
y="worls"
print(x+" " + y)
print(x.upper())
# Out:
# hello worls
# HELLO

# %%
#checking subsrtimgs
x="python is programmming language"
print("python" in x)
print("python   " in x)
# Out:
# True
# False

# %%
#string formatting
user="dhanushree"
age=22
print(f"your name {user} and you age is {age}")
# Out:
# your name dhanushree and you age is 22

# %%
print("apple"=="apple")
print("banana" < "apple")

# %%
#sets
#unordred,duplicates will be ignored
#true and 1 are treated as same
#can use (()) for creating a set than {}

this_set={"apple","banana","cherry","apple",1,True,False}
print(this_set)
print(len(this_set))
print(type(this_set))
# Out:
# {False, 1, 'banana', 'cherry', 'apple'}
# 5
# <class 'set'>

# %%
#accessing the set

this_set={"apple","banana","cherry","apple",1,True,False}
for x in this_set:
    print(x)
print("banana" in this_set)
# Out:
# False
# 1
# banana
# cherry
# apple
# True

# %%
this_set={"apple","banana","cherry","apple",1,True,False}
#print("banana" in this_set)
this_set.add('cherry')
print(this_set)
# Out:
# {False, 1, 'banana', 'cherry', 'apple'}

# %%
this_set={"apple","banana","cherry","apple",1,True,False}
print("banana" in this_set)
# Out:
# True

# %%
this_set={"apple","banana","cherry","apple",1,True,False}
this_set2={"oninon","tomato"}
this_set.add("grapre")              #qdding the item
print(this_set)
# Out:
# {False, 1, 'grapre', 'banana', 'cherry', 'apple'}

# %%
this_set={"apple","banana","cherry","apple",1,True,False}
this_set2={"oninon","tomato"}
this_set.update(this_set2)            #qdding the item
print(this_set)

# %%
tuples=("hello",1,23,("hi","a",24.5,("re",22,2.5)),45,49)
print(len(tuples))
value=tuples[3][3][0]
print(value)
# Out:
# 6
# re

# %%
user_name= input("Enter your name: ")
user_password=input("Enter your password: ")
cred={
    'ram':'1234','krish':345
}
if user_name in cred:

    if user_password==cred[user_name]:
        print("login succefull")
else:
    print("username not found")
# Out:
# username not found

# %%
list_data=["hii",22,33.5,[44.5,"hello",[1,4.5,"re",['e',24.5]]],44.5,45.2,"final"]
print(len(list_data))
list_data.insert(0,"hello")
print(list_data)
list_data.append(7)
print(list_data)
print(list_data[4][2][3][0])
del list_data[4][2][3][0]
list_data.insert([4][1],"hello")
# Out:
# 7
# ['hello', 'hii', 22, 33.5, [44.5, 'hello', [1, 4.5, 're', ['e', 24.5]]], 44.5, 45.2, 'final']
# ['hello', 'hii', 22, 33.5, [44.5, 'hello', [1, 4.5, 're', ['e', 24.5]]], 44.5, 45.2, 'final', 7]
# e
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[130], line 9
#       7 print(list_data[4][2][3][0])
#       8 del list_data[4][2][3][0]
# ----> 9 list_data.insert([4][1],"hello")
#
# IndexError: list index out of range

# %%
my_tuple=("abc",23,4)
my_tuple2=(33,55,5)
print(my_tuple+my_tuple2)
print(type(my_tuple2))
# Out:
# ('abc', 23, 4, 33, 55, 5)
# <class 'tuple'>

# %%
my_tuple=("abc",23,4)
x=list(my_tuple)
x[0]='what raa sudeep'
my_tuple=list(x)
print(my_tuple)
# Out:
# ['what raa sudeep', 23, 4]

# %%
my_set={"hello",2,2,"what ra sudeep",0}
my_set.add("hi")

# %%
from collections import Counter
text="mississippi"
count=Counter(text)
print(count)
# Out:
# Counter({'i': 4, 's': 4, 'p': 2, 'm': 1})
